# %% [markdown]
# # Qualitätsbewertung
#
# Insbesondere für die Generierung von Forschungsdaten sollte eine hohe Wiedergabetreue erreicht werden. Wie geht das?

# %%
from myst_nb import glue
from src.chart_metrics import c
glue("cool_text", c)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0f7f19566e0949cd8f47f81567cefe74" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0f7f19566e0949cd8f47f81567cefe74 = echarts.init(
#                     document.getElementById('0f7f19566e0949cd8f47f81567cefe74'), 'white', {renderer: 'canvas'});
#                 var option_0f7f19566e0949cd8f47f81567cefe74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# {glue:}`cool_text`
